# %% [markdown]
# # Back Testing

# %%
import roboquant as rq

rq.set_light_style()

# %%
feed = rq.feeds.YahooFeed.us_stocks_10()

# %%
strategy = rq.strategies.EMACrossover()
account = rq.run(feed, strategy)
print(account)
# Out:
# buying power : 1,367,842@USD
# cash         : 1,367,842@USD
# equity       : 3,526,623@USD
# positions    : 1075@JPM, 2430@XOM, 773@MSFT, 1206@AMZN, 824@AVGO, 1568@NVDA
# trades       : 518
# mkt value    : 2,158,781@USD
# orders       : none
# last update  : 2026-08-17 04:00:00+00:00

# %%
feed.plot("JPM", trades=account.trades);
